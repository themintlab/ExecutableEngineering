# %% [markdown]
# # Finite difference
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/themintlab/ExecutableEngineering/blob/main/chapters/differentiation_and_integration/finite_difference/finite_difference.ipynb)

# %% [markdown]
# Finite difference
